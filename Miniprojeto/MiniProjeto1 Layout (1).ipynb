# %% [markdown]
# ___
# # MINIPROJETO 1

# %% [markdown]
# ## <font color='red'>Felipe Rocha Sigiani</font>
# ___

# %% [markdown]
# ## <font color='blue'>Renda e o Desenvolvimento Humano</font>

# %% [markdown]
# ___
# ### Itens 1 a 3 - Resolução:

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from scipy import stats

print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Felipe Lenda Sigiani\Downloads

# %%
dados = pd.read_csv('tabela.csv',sep = ";", encoding='latin1')

# %%
vida = dados.S05_12

# %%
dados.S05_12.describe()
# Out:
# count    662.000000
# mean      68.560423
# std        7.370576
# min       40.000000
# 25%       64.000000
# 50%       69.000000
# 75%       73.000000
# max       96.000000
# Name: S05_12, dtype: float64

# %% [markdown]
# ___
# ### Itens 4 a 6 - Resolução:

# %%
plt.hist(x=vida, bins=(range(40,100,5)),normed = True,color='blue') # Plotagem do histograma
plt.title("Longevidade nas cidades")
plt.xlabel("Idade(em anos)")
plt.ylabel("Cidades")
x = np.linspace(stats.norm.ppf(40),
                stats.norm.ppf(90), 100)
plt.plot(x, stats.norm.pdf(x),
       'r-', lw=5, alpha=0.6, label='norm pdf')

x=np.linspace(40,100,500) # Valor inicial, Valor Final, Número de elementos
plt.plot(x, stats.norm.pdf(x,loc=media,scale=variancia),'black',alpha=0.8,lw=5) # Plota a densidade de probabilidade de distribuição

# %%
stats.norm.ppf(0.01)
# Out:
# -2.3263478740408408

# %%
df = 2.74

plt.hist(x=vida, bins=(range(40,100,5)),normed = True,color='blue') # Plotagem do histograma
plt.title("Longevidade nas cidades")
plt.xlabel("Idade(em anos)")
plt.ylabel("Cidades")


x = np.arange(40,100,1)
a = stats.t.pdf(x, df, loc=68, scale=7)
plt.plot(x, a,'r-', lw=5, alpha=0.6, label='t pdf')
plt.plot(x, stats.norm.pdf(x,loc=media,scale=variancia),'black',alpha=0.8,lw=5) # Plota a densidade de probabilidade de distribuição

# %% [markdown]
# ___
# ### Itens 7 a 9 - Resolução:

# %% [markdown]
# ___
# ### Itens 10 e 11 - Resolução:
