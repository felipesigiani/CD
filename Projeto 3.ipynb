# %% [markdown]
# # Projeto 2 - Ciência dos dados
#
# ## Eduardo Tirta
# ## Felipe Sigiani

# %%
# %matplotlib inline

import os
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import pandas as pd
import numpy as np

import statsmodels.api as sm1 #Usa OLS com X como matriz de planejamento
import statsmodels.formula.api as sm  #Usa OLS como no R

print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Felipe Lenda Sigiani\Documents\Estudos Felipe\2ºSemestre\Ciencia dos dados

# %%
dados = pd.read_excel('Indicator_Improved sanitation rural percent.xlsx',index_col=0)
dados1 = pd.read_excel("indicator_per capita total expenditure on health (ppp int. $).xlsx",index_col = 0)

# %%
dados.head()
# Out:
#                                                     1990  1991  1992  1993  \
# Proportion of the population using improved san...
# Abkhazia                                             NaN   NaN   NaN   NaN
# Afghanistan                                          NaN  27.0  27.0  27.0
# Akrotiri and Dhekelia                                NaN   NaN   NaN   NaN
# Albania                                             66.0  66.0  66.0  66.0
# Algeria                                             77.0  77.0  77.0  77.0
#
#                                                     1994  1995  1996  1997  \
# Proportion of the population using improved san...
# Abkhazia                                             NaN   NaN   NaN   NaN
# Afghanistan                                         27.0  27.0  27.0  27.0
# Akrotiri and Dhekelia                                NaN   NaN   NaN   NaN
# Albania                                             66.0  68.0  69.0  71.0
# ...

# %%
dados=dados[~np.isnan(dados.QUERO)]

# %%
dados.head()
# Out:
#                                                      1990   1991   1992  \
# Proportion of the population using improved san...
# Afghanistan                                           NaN   27.0   27.0
# Albania                                              66.0   66.0   66.0
# Algeria                                              77.0   77.0   77.0
# Andorra                                             100.0  100.0  100.0
# Angola                                                6.0    6.0    6.0
#
#                                                      1993   1994   1995  \
# Proportion of the population using improved san...
# Afghanistan                                          27.0   27.0   27.0
# Albania                                              66.0   66.0   68.0
# Algeria                                              77.0   78.0   78.0
# Andorra                                             100.0  100.0  100.0
# ...

# %%
d = pd.DataFrame()

# %%
d = dados.QUERO

# %%
d.head()
# Out:
# Proportion of the population using improved sanitation facilities, rural
# Afghanistan     30.0
# Albania         93.0
# Algeria         88.0
# Andorra        100.0
# Angola          19.0
# Name: QUERO, dtype: float64

# %%
d1 = pd.DataFrame()

# %%
dados1.head()
# Out:
#                                                           1995        1996  \
# Per capita total expenditure on health (PPP int...
# Abkhazia                                                   NaN         NaN
# Afghanistan                                                NaN         NaN
# Akrotiri and Dhekelia                                      NaN         NaN
# Albania                                             105.870766  145.874213
# Algeria                                             192.243807  180.373326
#
#                                                           1997        1998  \
# Per capita total expenditure on health (PPP int...
# Abkhazia                                                   NaN         NaN
# Afghanistan                                                NaN         NaN
# Akrotiri and Dhekelia                                      NaN         NaN
# Albania                                             156.120295  183.802111
# ...

# %%
dados1=dados1[~np.isnan(dados1.Quero)]

# %%
d1 = dados1.Quero

# %%
d1.head()
# Out:
# Per capita total expenditure on health (PPP int. $)
# Afghanistan      44.465952
# Albania         577.275816
# Algeria         330.006155
# Andorra        3254.524918
# Angola          168.130557
# Name: Quero, dtype: float64
